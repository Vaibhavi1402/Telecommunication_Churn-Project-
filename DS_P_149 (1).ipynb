# %%
# Load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plp
import seaborn as sns

# %%
data=pd.read_csv('F:\\python\\Datascience project\\project 3\\telecommunications_churn.csv')

# %%
data.head()
# Out:
#    account_length  voice_mail_plan  voice_mail_messages  day_mins  \
# 0             128                1                   25     265.1
# 1             107                1                   26     161.6
# 2             137                0                    0     243.4
# 3              84                0                    0     299.4
# 4              75                0                    0     166.7
#
#    evening_mins  night_mins  international_mins  customer_service_calls  \
# 0         197.4       244.7                10.0                       1
# 1         195.5       254.4                13.7                       1
# 2         121.2       162.6                12.2                       0
# 3          61.9       196.9                 6.6                       2
# 4         148.3       186.9                10.1                       3
#
#    international_plan  day_calls  day_charge  evening_calls  evening_charge  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.shape
# Out:
# (3333, 19)

# %%
data.isnull().sum()
# Out:
# account_length            0
# voice_mail_plan           0
# voice_mail_messages       0
# day_mins                  0
# evening_mins              0
# night_mins                0
# international_mins        0
# customer_service_calls    0
# international_plan        0
# day_calls                 0
# day_charge                0
# evening_calls             0
# evening_charge            0
# night_calls               0
# night_charge              0
# international_calls       0
# international_charge      0
# total_charge              0
# churn                     0
# dtype: int64

# %%
data.dtypes
# Out:
# account_length              int64
# voice_mail_plan             int64
# voice_mail_messages         int64
# day_mins                  float64
# evening_mins              float64
# night_mins                float64
# international_mins        float64
# customer_service_calls      int64
# international_plan          int64
# day_calls                   int64
# day_charge                float64
# evening_calls               int64
# evening_charge            float64
# night_calls                 int64
# night_charge              float64
# international_calls         int64
# international_charge      float64
# total_charge              float64
# churn                       int64
# dtype: object

# %%
data.nunique()
# Out:
# account_length             212
# voice_mail_plan              2
# voice_mail_messages         46
# day_mins                  1667
# evening_mins              1611
# night_mins                1591
# international_mins         162
# customer_service_calls      10
# international_plan           2
# day_calls                  119
# day_charge                1667
# evening_calls              123
# evening_charge            1440
# night_calls                120
# night_charge               933
# international_calls         21
# international_charge       162
# total_charge              2227
# churn                        2
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   account_length          3333 non-null   int64
#  1   voice_mail_plan         3333 non-null   int64
#  2   voice_mail_messages     3333 non-null   int64
#  3   day_mins                3333 non-null   float64
#  4   evening_mins            3333 non-null   float64
#  5   night_mins              3333 non-null   float64
#  6   international_mins      3333 non-null   float64
#  7   customer_service_calls  3333 non-null   int64
#  8   international_plan      3333 non-null   int64
#  9   day_calls               3333 non-null   int64
#  10  day_charge              3333 non-null   float64
#  11  evening_calls           3333 non-null   int64
#  12  evening_charge          3333 non-null   float64
#  13  night_calls             3333 non-null   int64
# ...

# %%
data.describe()
# Out:
#        account_length  voice_mail_plan  voice_mail_messages     day_mins  \
# count     3333.000000      3333.000000          3333.000000  3333.000000
# mean       101.064806         0.276628             8.099010   179.775098
# std         39.822106         0.447398            13.688365    54.467389
# min          1.000000         0.000000             0.000000     0.000000
# 25%         74.000000         0.000000             0.000000   143.700000
# 50%        101.000000         0.000000             0.000000   179.400000
# 75%        127.000000         1.000000            20.000000   216.400000
# max        243.000000         1.000000            51.000000   350.800000
#
#        evening_mins   night_mins  international_mins  customer_service_calls  \
# count   3333.000000  3333.000000         3333.000000             3333.000000
# mean     200.980348   200.872037           10.237294                1.562856
# std       50.713844    50.573847            2.791840                1.315491
# ...

# %%
data.mean()
# Out:
# account_length            101.064806
# voice_mail_plan             0.276628
# voice_mail_messages         8.099010
# day_mins                  179.775098
# evening_mins              200.980348
# night_mins                200.872037
# international_mins         10.237294
# customer_service_calls      1.562856
# international_plan          0.096910
# day_calls                 100.435644
# day_charge                 30.562307
# evening_calls             100.114311
# evening_charge             17.083540
# night_calls               100.107711
# night_charge                9.039325
# international_calls         4.479448
# international_charge        2.764581
# total_charge               59.449754
# churn                       0.144914
# dtype: float64

# %%
data.median()
# Out:
# account_length            101.00
# voice_mail_plan             0.00
# voice_mail_messages         0.00
# day_mins                  179.40
# evening_mins              201.40
# night_mins                201.20
# international_mins         10.30
# customer_service_calls      1.00
# international_plan          0.00
# day_calls                 101.00
# day_charge                 30.50
# evening_calls             100.00
# evening_charge             17.12
# night_calls               100.00
# night_charge                9.05
# international_calls         4.00
# international_charge        2.78
# total_charge               59.47
# churn                       0.00
# dtype: float64

# %%
data.corr()
# Out:
#                         account_length  voice_mail_plan  voice_mail_messages  \
# account_length                1.000000         0.002918            -0.004628
# voice_mail_plan               0.002918         1.000000             0.956927
# voice_mail_messages          -0.004628         0.956927             1.000000
# day_mins                      0.006216        -0.001684             0.000778
# evening_mins                 -0.006757         0.021545             0.017562
# night_mins                   -0.008955         0.006079             0.007681
# international_mins            0.009514        -0.001318             0.002856
# customer_service_calls       -0.003796        -0.017824            -0.013263
# international_plan            0.024735         0.006006             0.008745
# day_calls                     0.038470        -0.011086            -0.009548
# day_charge                    0.006214        -0.001686             0.000776
# ...

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Length: 3333, dtype: bool

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (3333, 19)

# %%
data.columns
# Out:
# Index(['account_length', 'voice_mail_plan', 'voice_mail_messages', 'day_mins',
#        'evening_mins', 'night_mins', 'international_mins',
#        'customer_service_calls', 'international_plan', 'day_calls',
#        'day_charge', 'evening_calls', 'evening_charge', 'night_calls',
#        'night_charge', 'international_calls', 'international_charge',
#        'total_charge', 'churn'],
#       dtype='object')

# %%
data['account_length'].unique()
# Out:
# array([128, 107, 137,  84,  75, 118, 121, 147, 117, 141,  65,  74, 168,
#         95,  62, 161,  85,  93,  76,  73,  77, 130, 111, 132, 174,  57,
#         54,  20,  49, 142, 172,  12,  72,  36,  78, 136, 149,  98, 135,
#         34, 160,  64,  59, 119,  97,  52,  60,  10,  96,  87,  81,  68,
#        125, 116,  38,  40,  43, 113, 126, 150, 138, 162,  90,  50,  82,
#        144,  46,  70,  55, 106,  94, 155,  80, 104,  99, 120, 108, 122,
#        157, 103,  63, 112,  41, 193,  61,  92, 131, 163,  91, 127, 110,
#        140,  83, 145,  56, 151, 139,   6, 115, 146, 185, 148,  32,  25,
#        179,  67,  19, 170, 164,  51, 208,  53, 105,  66,  86,  35,  88,
#        123,  45, 100, 215,  22,  33, 114,  24, 101, 143,  48,  71, 167,
#         89, 199, 166, 158, 196, 209,  16,  39, 173, 129,  44,  79,  31,
#        124,  37, 159, 194, 154,  21, 133, 224,  58,  11, 109, 102, 165,
#         18,  30, 176,  47, 190, 152,  26,  69, 186, 171,  28, 153, 169,
# ...

# %%
data['voice_mail_plan'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data['voice_mail_messages'].unique()
# Out:
# array([25, 26,  0, 24, 37, 27, 33, 39, 30, 41, 28, 34, 46, 29, 35, 21, 32,
#        42, 36, 22, 23, 43, 31, 38, 40, 48, 18, 17, 45, 16, 20, 14, 19, 51,
#        15, 11, 12, 47,  8, 44, 49,  4, 10, 13, 50,  9], dtype=int64)

# %%
data['day_mins'].unique()
# Out:
# array([265.1, 161.6, 243.4, ..., 321.1, 231.1, 180.8])

# %%
data['evening_mins'].unique()
# Out:
# array([197.4, 195.5, 121.2, ..., 153.4, 288.8, 265.9])

# %%
data['night_mins'].unique()
# Out:
# array([244.7, 254.4, 162.6, ..., 280.9, 120.1, 279.1])

# %%
data['customer_service_calls'].unique()
# Out:
# array([1, 0, 2, 3, 4, 5, 7, 9, 6, 8], dtype=int64)

# %%
data['international_plan'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['day_calls'].unique()
# Out:
# array([110, 123, 114,  71, 113,  98,  88,  79,  97,  84, 137, 127,  96,
#         70,  67, 139,  66,  90, 117,  89, 112, 103,  86,  76, 115,  73,
#        109,  95, 105, 121, 118,  94,  80, 128,  64, 106, 102,  85,  82,
#         77, 120, 133, 135, 108,  57,  83, 129,  91,  92,  74,  93, 101,
#        146,  72,  99, 104, 125,  61, 100,  87, 131,  65, 124, 119,  52,
#         68, 107,  47, 116, 151, 126, 122, 111, 145,  78, 136, 140, 148,
#         81,  55,  69, 158, 134, 130,  63,  53,  75, 141, 163,  59, 132,
#        138,  54,  58,  62, 144, 143, 147,  36,  40, 150,  56,  51, 165,
#         30,  48,  60,  42,   0,  45, 160, 149, 152, 142, 156,  35,  49,
#        157,  44], dtype=int64)

# %%
data['day_charge'].unique()
# Out:
# array([45.07, 27.47, 41.38, ..., 54.59, 39.29, 30.74])

# %%
data['evening_calls'].unique()
# Out:
# array([ 99, 103, 110,  88, 122, 101, 108,  94,  80, 111,  83, 148,  71,
#         75,  76,  97,  90,  65,  93, 121, 102,  72, 112, 100,  84, 109,
#         63, 107, 115, 119, 116,  92,  85,  98, 118,  74, 117,  58,  96,
#         66,  67,  62,  77, 164, 126, 142,  64, 104,  79,  95,  86, 105,
#         81, 113, 106,  59,  48,  82,  87, 123, 114, 140, 128,  60,  78,
#        125,  91,  46, 138, 129,  89, 133, 136,  57, 135, 139,  51,  70,
#        151, 137, 134,  73, 152, 168,  68, 120,  69, 127, 132, 143,  61,
#        124,  42,  54, 131,  52, 149,  56,  37, 130,  49, 146, 147,  55,
#         12,  50, 157, 155,  45, 144,  36, 156,  53, 141,  44, 153, 154,
#        150,  43,   0, 145, 159, 170], dtype=int64)

# %%
data['evening_charge'].unique()
# Out:
# array([16.78, 16.62, 10.3 , ..., 13.04, 24.55, 22.6 ])

# %%
data['night_calls'].unique()
# Out:
# array([ 91, 103, 104,  89, 121, 118,  96,  90,  97, 111,  94, 128, 115,
#         99,  75, 108,  74, 133,  64,  78, 105,  68, 102, 148,  98, 116,
#         71, 109, 107, 135,  92,  86, 127,  79,  87, 129,  57,  77,  95,
#         54, 106,  53,  67, 139,  60, 100,  61,  73, 113,  76, 119,  88,
#         84,  62, 137,  72, 142, 114, 126, 122,  81, 123, 117,  82,  80,
#        120, 130, 134,  59, 112, 132, 110, 101, 150,  69, 131,  83,  93,
#        124, 136, 125,  66, 143,  58,  55,  85,  56,  70,  46,  42, 152,
#         44, 145,  50, 153,  49, 175,  63, 138, 154, 140, 141, 146,  65,
#         51, 151, 158, 155, 157, 147, 144, 149, 166,  52,  33, 156,  38,
#         36,  48, 164], dtype=int64)

# %%
data['night_charge'].unique()
# Out:
# array([11.01, 11.45,  7.32,  8.86,  8.41,  9.18,  9.57,  9.53,  9.71,
#        14.69,  9.4 ,  8.82,  6.35,  8.65,  9.14,  7.23,  4.02,  5.83,
#         7.46,  8.68,  9.43,  8.18,  8.53, 10.67, 11.28,  8.22,  4.59,
#         8.17,  8.04, 11.27, 11.08, 13.2 , 12.61,  9.61,  6.88,  5.82,
#        10.25,  4.58,  8.47,  8.45,  5.5 , 14.02,  8.03, 11.94,  7.34,
#         6.06, 10.9 ,  6.44,  3.18, 10.66, 11.21, 12.73, 10.28, 12.16,
#         6.34,  8.15,  5.84,  8.52,  7.5 ,  7.48,  6.21, 11.95,  7.15,
#         9.63,  7.1 ,  6.91,  6.69, 13.29, 11.46,  7.76,  6.86,  8.16,
#        12.15,  7.79,  7.99, 10.29, 10.08, 12.53,  7.91, 10.02,  8.61,
#        14.54,  8.21,  9.09,  4.93, 11.39, 11.88,  5.75,  7.83,  8.59,
#         7.52, 12.38,  7.21,  5.81,  8.1 , 11.04, 11.19,  8.55,  8.42,
#         9.76,  9.87, 10.86,  5.36, 10.03, 11.15,  9.51,  6.22,  2.59,
#         7.65,  6.45,  9.  ,  6.4 ,  9.94,  5.08, 10.23, 11.36,  6.97,
# ...

# %%
data['international_calls'].unique()
# Out:
# array([ 3,  5,  7,  6,  4,  2,  9, 19,  1, 10, 15,  8, 11,  0, 12, 13, 18,
#        14, 16, 20, 17], dtype=int64)

# %%
data['international_charge'].unique()
# Out:
# array([2.7 , 3.7 , 3.29, 1.78, 2.73, 1.7 , 2.03, 1.92, 2.35, 3.02, 3.43,
#        2.46, 3.32, 3.54, 1.46, 3.73, 2.19, 3.51, 2.86, 1.54, 2.57, 2.08,
#        2.78, 4.19, 3.97, 3.  , 3.83, 3.4 , 3.19, 2.24, 3.92, 2.84, 2.54,
#        3.94, 2.48, 0.95, 2.3 , 3.56, 2.  , 2.38, 2.97, 2.11, 1.84, 3.08,
#        2.51, 2.62, 2.75, 2.16, 1.57, 3.27, 3.24, 3.13, 2.21, 1.67, 1.97,
#        1.65, 3.16, 4.05, 2.65, 3.35, 2.32, 2.94, 3.75, 2.4 , 2.13, 1.43,
#        1.19, 3.38, 3.05, 2.43, 2.59, 3.59, 5.4 , 1.94, 1.73, 3.81, 3.86,
#        1.86, 3.11, 4.27, 3.46, 4.37, 0.  , 3.21, 2.67, 2.27, 2.92, 3.62,
#        2.89, 4.75, 1.27, 0.73, 3.65, 3.48, 3.89, 2.81, 1.81, 4.16, 1.22,
#        1.76, 4.21, 1.59, 5.1 , 2.05, 1.35, 1.89, 3.78, 4.86, 4.32, 4.  ,
#        1.  , 0.54, 1.3 , 4.13, 1.62, 3.67, 4.64, 4.73, 1.51, 4.91, 0.97,
#        4.46, 1.24, 1.38, 1.11, 4.4 , 4.02, 4.43, 4.51, 0.35, 4.1 , 4.08,
#        4.29, 1.49, 4.35, 1.08, 4.56, 1.4 , 1.13, 4.24, 4.59, 1.05, 1.03,
# ...

# %%
data['total_charge'].unique()
# Out:
# array([75.56, 59.24, 62.29, ..., 54.4 , 67.74, 77.01])

# %%
data['churn'].value_counts()
# 0= No Churn
# 1= Churn
# Out:
# 0    2850
# 1     483
# Name: churn, dtype: int64

# %% [markdown]
# # Correlation

# %%
corr_matrix=data.corr()
corr_matrix
# Out:
#                         account_length  voice_mail_plan  voice_mail_messages  \
# account_length                1.000000         0.002918            -0.004628
# voice_mail_plan               0.002918         1.000000             0.956927
# voice_mail_messages          -0.004628         0.956927             1.000000
# day_mins                      0.006216        -0.001684             0.000778
# evening_mins                 -0.006757         0.021545             0.017562
# night_mins                   -0.008955         0.006079             0.007681
# international_mins            0.009514        -0.001318             0.002856
# customer_service_calls       -0.003796        -0.017824            -0.013263
# international_plan            0.024735         0.006006             0.008745
# day_calls                     0.038470        -0.011086            -0.009548
# day_charge                    0.006214        -0.001686             0.000776
# ...

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(15,7))
sns.heatmap(corr_matrix,annot=True)
plt.show()

# %% [markdown]
# # Data Visualization

# %%
# Histogram
import matplotlib.pyplot as plt
for i in data.columns:
    plt.title(i)
    plt.hist(data[i])
    plt.show()

# %% [markdown]
# # Checking for outliers

# %%
for i in data.columns:
    data.boxplot(column=i)
    plt.ylabel(i)
    plt.title(i)
    plt.show()

# %% [markdown]
# # Feature Engineering

# %%
data.shape
# Out:
# (3333, 19)

# %%
x=data.iloc[:,0:18]
y=data.iloc[:,18]

# %%
##Feature Importance using Decision Tree
from sklearn.tree import  DecisionTreeClassifier
# feature extraction
model = DecisionTreeClassifier()
model.fit(x,y)
print(model.feature_importances_)
# Out:
# [0.01097261 0.10856684 0.00608982 0.00593324 0.00700077 0.01063262
#  0.09103661 0.11154862 0.06875161 0.01598475 0.00907975 0.01486515
#  0.00857253 0.00877367 0.01423078 0.08067609 0.01504072 0.41224383]

# %%
# Feature Extraction with RFE
from sklearn.feature_selection import RFE
from sklearn.svm import SVR
model =DecisionTreeClassifier()
selector = RFE(model, n_features_to_select=10, step=1)
selector = selector.fit(x,y)
print(selector.support_)
print(selector.ranking_)
# Out:
# [ True False  True False False  True False  True  True False False  True
#   True False False  True  True  True]
# [1 8 1 7 9 1 6 1 1 2 4 1 1 5 3 1 1 1]

# %% [markdown]
# # Dropping Variables

# %%
#delete these variables as they are 100% related(from corelation matrix) 
# Delete these variables voice_mail_plan,Voice_mail_messages,day_mins as they are 96% correlated 
data.drop(labels=['international_charge','night_charge','evening_charge','day_charge','voice_mail_plan','voice_mail_messages'], axis=1, inplace=True)
data
# Out:
#       account_length  day_mins  evening_mins  night_mins  international_mins  \
# 0                128     265.1         197.4       244.7                10.0
# 1                107     161.6         195.5       254.4                13.7
# 2                137     243.4         121.2       162.6                12.2
# 3                 84     299.4          61.9       196.9                 6.6
# 4                 75     166.7         148.3       186.9                10.1
# ...              ...       ...           ...         ...                 ...
# 3328             192     156.2         215.5       279.1                 9.9
# 3329              68     231.1         153.4       191.3                 9.6
# 3330              28     180.8         288.8       191.9                14.1
# 3331             184     213.8         159.6       139.2                 5.0
# 3332              74     234.4         265.9       241.4                13.7
#
# ...

# %%
df=data
df
# Out:
#       account_length  day_mins  evening_mins  night_mins  international_mins  \
# 0                128     265.1         197.4       244.7                10.0
# 1                107     161.6         195.5       254.4                13.7
# 2                137     243.4         121.2       162.6                12.2
# 3                 84     299.4          61.9       196.9                 6.6
# 4                 75     166.7         148.3       186.9                10.1
# ...              ...       ...           ...         ...                 ...
# 3328             192     156.2         215.5       279.1                 9.9
# 3329              68     231.1         153.4       191.3                 9.6
# 3330              28     180.8         288.8       191.9                14.1
# 3331             184     213.8         159.6       139.2                 5.0
# 3332              74     234.4         265.9       241.4                13.7
#
# ...

# %% [markdown]
# # Correlation after dopping variables

# %%
correlation=df.corr()
correlation
# Out:
#                         account_length  day_mins  evening_mins  night_mins  \
# account_length                1.000000  0.006216     -0.006757   -0.008955
# day_mins                      0.006216  1.000000      0.007043    0.004323
# evening_mins                 -0.006757  0.007043      1.000000   -0.012584
# night_mins                   -0.008955  0.004323     -0.012584    1.000000
# international_mins            0.009514 -0.010155     -0.011035   -0.015207
# customer_service_calls       -0.003796 -0.013423     -0.012985   -0.009288
# international_plan            0.024735  0.049396      0.019100   -0.028905
# day_calls                     0.038470  0.006750     -0.021451    0.022938
# evening_calls                 0.019260  0.015769     -0.011430   -0.002093
# night_calls                  -0.013176  0.022972      0.007586    0.011204
# international_calls           0.020661  0.008033      0.002541   -0.012353
# ...

# %% [markdown]
# # Heat map after dropping variables

# %%
plt.figure(figsize=(15,7))
sns.heatmap(correlation,annot=True)
plt.show()

# %%
print(df['churn'].value_counts())
sns.countplot(df['churn'])
# Out:
# 0    2850
# 1     483
# Name: churn, dtype: int64
# C:\Users\RAJ\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='churn', ylabel='count'>

# %%
X=df.iloc[:,0:12]
Y=df.iloc[:,12]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Balancing data

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(sampling_strategy='minority')
x_sm,y_sm= smote.fit_resample(x_scaled,Y)

# %%
from sklearn import preprocessing
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import pickle
from sklearn.metrics import f1_score,accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.model_selection import KFold

# %%
X_train,X_test,y_train,y_test=train_test_split(x_sm,y_sm,test_size=0.25,random_state=15,stratify=y_sm)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4275, 12)
# (1425, 12)
# (4275,)
# (1425,)

# %% [markdown]
# # Model Building

# %% [markdown]
# # 1.Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score
LR = LogisticRegression(C=5, penalty='l2', random_state=7)
LR.fit(X_train,y_train)
y_pred_test_lr=LR.predict(X_test)
y_pred_train_lr=LR.predict(X_train)

# print classification report
print(classification_report(y_test, y_pred_test_lr))
print(classification_report(y_train, y_pred_train_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76       713
#            1       0.76      0.76      0.76       712
#
#     accuracy                           0.76      1425
#    macro avg       0.76      0.76      0.76      1425
# weighted avg       0.76      0.76      0.76      1425
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76      2137
#            1       0.76      0.76      0.76      2138
#
#     accuracy                           0.76      4275
#    macro avg       0.76      0.76      0.76      4275
# weighted avg       0.76      0.76      0.76      4275

# %%
#print accuracy
print(LR.score(x_sm,y_sm))
print(accuracy_score(y_test, y_pred_test_lr))
print(accuracy_score(y_train, y_pred_train_lr))
# Out:
# 0.7631578947368421
# 0.7628070175438596
# 0.7632748538011696

# %%
from sklearn.neural_network import MLPClassifier
import sklearn.metrics as metrics
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from pandas.plotting import scatter_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, plot_confusion_matrix, precision_recall_fscore_support
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
def PlotRoc():
    plt.figure()
    fpr, tpr, threshold = metrics.roc_curve(y_test, y_pred_test_lr)
    roc_auc = metrics.auc(fpr, tpr)
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0,1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.plot([0,1], [0,1], 'k--' )
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
print(classification_report(y_test, y_pred_test_lr))
print(classification_report(y_train, y_pred_train_lr))
confusion_matrix = plot_confusion_matrix(LR, X_test, y_test)
PlotRoc()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76       713
#            1       0.76      0.76      0.76       712
#
#     accuracy                           0.76      1425
#    macro avg       0.76      0.76      0.76      1425
# weighted avg       0.76      0.76      0.76      1425
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76      2137
#            1       0.76      0.76      0.76      2138
#
#     accuracy                           0.76      4275
#    macro avg       0.76      0.76      0.76      4275
# weighted avg       0.76      0.76      0.76      4275

# %%
# Evaluate using cross validation:
from sklearn.model_selection import KFold
kfold=KFold(n_splits=10,random_state=7,shuffle=True)
model=LogisticRegression(max_iter=400)
results=cross_val_score(model,x_sm,y_sm,cv=kfold)
results.mean()*100
# Out:
# 76.45614035087719

# %% [markdown]
# # 2.Navie_Bayes

# %%
# Navie bayes
from sklearn.naive_bayes import GaussianNB
from sklearn.mixture import GaussianMixture
# train_test
gn=GaussianNB()
gn.fit(X_train,y_train)
y_pred_test_nb=gn.predict(X_test)
y_pred_train_nb=gn.predict(X_train)
print(gn.score(x_sm,y_sm))
print('Accuracy:', metrics.accuracy_score(y_test,y_pred_test_nb))
print('Accuracy:', metrics.accuracy_score(y_train,y_pred_train_nb))
# Out:
# 0.8105263157894737
# Accuracy: 0.8035087719298246
# Accuracy: 0.8128654970760234

# %%
# Evaluate using cross validation:
from sklearn.model_selection import KFold
kfold=KFold(n_splits=10,random_state=7,shuffle=True)
model=GaussianNB()
results=cross_val_score(model,x_sm,y_sm,cv=kfold)
results.mean()*100
# Out:
# 81.17543859649123

# %%
print(classification_report(y_train,y_pred_train_nb))
print(classification_report(y_test,y_pred_test_nb))
confusion_matrix = plot_confusion_matrix(gn, X_test, y_test)
PlotRoc()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.82      2137
#            1       0.83      0.78      0.81      2138
#
#     accuracy                           0.81      4275
#    macro avg       0.81      0.81      0.81      4275
# weighted avg       0.81      0.81      0.81      4275
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81       713
#            1       0.82      0.77      0.80       712
#
#     accuracy                           0.80      1425
#    macro avg       0.80      0.80      0.80      1425
# weighted avg       0.80      0.80      0.80      1425

# %% [markdown]
# # 3.Decision Tree

# %%
# Decision tree classifier
from sklearn.tree import DecisionTreeClassifier
#train_test
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
y_pred_test_dt=dt.predict(X_test)
y_pred_train_dt=dt.predict(X_train)
print(dt.score(x_sm,y_sm))
print('Accuracy:', metrics.accuracy_score(y_test,y_pred_test_dt))
print('Accuracy:', metrics.accuracy_score(y_train,y_pred_train_dt))
# Out:
# 0.9778947368421053
# Accuracy: 0.911578947368421
# Accuracy: 1.0

# %%
# Evaluate using cross validation:
from sklearn.model_selection import KFold
kfold=KFold(n_splits=10,random_state=7,shuffle=True)
model=DecisionTreeClassifier()
results=cross_val_score(model,x_sm,y_sm,cv=kfold)
results.mean()*100
# Out:
# 92.56140350877195

# %%
print(classification_report(y_train,y_pred_train_dt))
print(classification_report(y_test,y_pred_test_dt))
confusion_matrix = plot_confusion_matrix(dt, X_test, y_test)
PlotRoc()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2137
#            1       1.00      1.00      1.00      2138
#
#     accuracy                           1.00      4275
#    macro avg       1.00      1.00      1.00      4275
# weighted avg       1.00      1.00      1.00      4275
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       713
#            1       0.89      0.93      0.91       712
#
#     accuracy                           0.91      1425
#    macro avg       0.91      0.91      0.91      1425
# weighted avg       0.91      0.91      0.91      1425

# %% [markdown]
# # 4.Support Vector Machine

# %%
from sklearn.svm import LinearSVC, SVC
#train_test
svm=LinearSVC()
svm.fit(X_train,y_train)
y_pred_test_svm=svm.predict(X_test)
y_pred_train_svm=svm.predict(X_train)
print(svm.score(x_sm,y_sm))
print('Accuracy:',metrics.accuracy_score(y_test,y_pred_test_svm))
print('Accuracy:',metrics.accuracy_score(y_train,y_pred_train_svm))
# Out:
# 0.7617543859649123
# Accuracy: 0.7607017543859649
# Accuracy: 0.7621052631578947
# C:\Users\RAJ\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
# Evaluate using cross validation:
from sklearn.model_selection import KFold
kfold=KFold(n_splits=12,random_state=7,shuffle=True)
model=LinearSVC()
results=cross_val_score(model,x_sm,y_sm,cv=kfold)
results.mean()*100
# Out:
# C:\Users\RAJ\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\RAJ\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\RAJ\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\RAJ\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# ...

# %%
print(classification_report(y_train,y_pred_train_svm))
print(classification_report(y_test,y_pred_test_svm))
confusion_matrix = plot_confusion_matrix(svm, X_test, y_test)
PlotRoc()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76      2137
#            1       0.76      0.76      0.76      2138
#
#     accuracy                           0.76      4275
#    macro avg       0.76      0.76      0.76      4275
# weighted avg       0.76      0.76      0.76      4275
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76       713
#            1       0.76      0.76      0.76       712
#
#     accuracy                           0.76      1425
#    macro avg       0.76      0.76      0.76      1425
# weighted avg       0.76      0.76      0.76      1425

# %% [markdown]
# # 5.Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
#train_test
rf=RandomForestClassifier()
rf.fit(X_train,y_train)
y_pred_test_rf=rf.predict(X_test)
y_pred_train_rf=rf.predict(X_train)
print(rf.score(x_sm,y_sm))
print('Accuracy:',metrics.accuracy_score(y_test,y_pred_test_rf))
print('Accuracy:',metrics.accuracy_score(y_train,y_pred_train_rf))
# Out:
# 0.9892982456140351
# Accuracy: 0.9571929824561404
# Accuracy: 1.0

# %%
# Evaluate using cross validation:
from sklearn.model_selection import KFold
kfold=KFold(n_splits=10,random_state=7,shuffle=True)
model=RandomForestClassifier()
results=cross_val_score(model,x_sm,y_sm,cv=kfold)
results.mean()*100
# Out:
# 96.22807017543862

# %%
print(classification_report(y_train,y_pred_train_rf))
print(classification_report(y_test,y_pred_test_rf))
confusion_matrix = plot_confusion_matrix(rf, X_test, y_test)
PlotRoc()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2137
#            1       1.00      1.00      1.00      2138
#
#     accuracy                           1.00      4275
#    macro avg       1.00      1.00      1.00      4275
# weighted avg       1.00      1.00      1.00      4275
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       713
#            1       0.97      0.95      0.96       712
#
#     accuracy                           0.96      1425
#    macro avg       0.96      0.96      0.96      1425
# weighted avg       0.96      0.96      0.96      1425

# %% [markdown]
# # 6.KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
#train_test
knn=KNeighborsClassifier()
knn.fit(X_train,y_train)
y_pred_test_knn=knn.predict(X_test)
y_pred_train_knn=knn.predict(X_train)
print(knn.score(x_sm,y_sm))
print('Accuracy:',metrics.accuracy_score(y_test,y_pred_test_knn))
print('Accuracy:',metrics.accuracy_score(y_train,y_pred_train_knn))
# Out:
# 0.9163157894736842
# Accuracy: 0.8947368421052632
# Accuracy: 0.9235087719298246

# %%
# Evaluate using cross validation:
from sklearn.model_selection import KFold
kfold=KFold(n_splits=10,random_state=7,shuffle=True)
model=KNeighborsClassifier()
results=cross_val_score(model,x_sm,y_sm,cv=kfold)
results.mean()*100
# Out:
# 90.14035087719299

# %%
print(classification_report(y_train,y_pred_train_knn))
print(classification_report(y_test,y_pred_test_knn))
confusion_matrix = plot_confusion_matrix(knn, X_test, y_test)
PlotRoc()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92      2137
#            1       0.87      1.00      0.93      2138
#
#     accuracy                           0.92      4275
#    macro avg       0.93      0.92      0.92      4275
# weighted avg       0.93      0.92      0.92      4275
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.80      0.88       713
#            1       0.83      0.99      0.90       712
#
#     accuracy                           0.89      1425
#    macro avg       0.91      0.89      0.89      1425
# weighted avg       0.91      0.89      0.89      1425

# %% [markdown]
# # 7.Ada Boost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
#train_test
Ada=AdaBoostClassifier()
Ada.fit(X_train,y_train)
y_pred_test_Ada=Ada.predict(X_test)
y_pred_train_Ada=Ada.predict(X_train)
print(Ada.score(x_sm,y_sm))
print('Accuracy:',metrics.accuracy_score(y_test,y_pred_test_Ada))
print('Accuracy:',metrics.accuracy_score(y_train,y_pred_train_Ada))
# Out:
# 0.9049122807017543
# Accuracy: 0.9045614035087719
# Accuracy: 0.9050292397660818

# %%
# Evaluate using cross validation:
from sklearn.model_selection import KFold
kfold=KFold(n_splits=10,random_state=7,shuffle=True)
model=AdaBoostClassifier()
results=cross_val_score(model,x_sm,y_sm,cv=kfold)
results.mean()*100
# Out:
# 89.63157894736841

# %%
print(classification_report(y_train,y_pred_train_knn))
print(classification_report(y_test,y_pred_test_knn))
confusion_matrix = plot_confusion_matrix(Ada, X_test, y_test)
PlotRoc()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92      2137
#            1       0.87      1.00      0.93      2138
#
#     accuracy                           0.92      4275
#    macro avg       0.93      0.92      0.92      4275
# weighted avg       0.93      0.92      0.92      4275
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.80      0.88       713
#            1       0.83      0.99      0.90       712
#
#     accuracy                           0.89      1425
#    macro avg       0.91      0.89      0.89      1425
# weighted avg       0.91      0.89      0.89      1425

# %% [markdown]
# # 8.XG Boost

# %%
from xgboost import XGBClassifier

# %%
#train_test
xgb=XGBClassifier()
xgb.fit(X_train,y_train)
y_pred_test_xgb=xgb.predict(X_test)
y_pred_train_xgb=xgb.predict(X_train)
print(xgb.score(x_sm,y_sm))
print('Accuracy:',metrics.accuracy_score(y_test,y_pred_test_xgb))
print('Accuracy:',metrics.accuracy_score(y_train,y_pred_train_xgb))
# Out:
# 0.9933333333333333
# Accuracy: 0.9733333333333334
# Accuracy: 1.0

# %%
# Evaluate using cross validation:
from sklearn.model_selection import KFold
kfold=KFold(n_splits=10,random_state=7,shuffle=True)
model=XGBClassifier()
results=cross_val_score(model,x_sm,y_sm,cv=kfold)
results.mean()*100
# Out:
# 97.36842105263158

# %%
print(classification_report(y_train,y_pred_train_knn))
print(classification_report(y_test,y_pred_test_knn))
confusion_matrix = plot_confusion_matrix(xgb, X_test, y_test)
PlotRoc()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92      2137
#            1       0.87      1.00      0.93      2138
#
#     accuracy                           0.92      4275
#    macro avg       0.93      0.92      0.92      4275
# weighted avg       0.93      0.92      0.92      4275
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.80      0.88       713
#            1       0.83      0.99      0.90       712
#
#     accuracy                           0.89      1425
#    macro avg       0.91      0.89      0.89      1425
# weighted avg       0.91      0.89      0.89      1425

# %%
Accuracies=pd.DataFrame({"Model":["Logistic Regression","Navie_Bayes","Decision_Tree","SVM","Random_Forest_Classifier","KNN","Ada_Boost_Classifier","XGB"],"Testing_Accuracy":[accuracy_score(y_test, y_pred_test_lr),accuracy_score(y_test, y_pred_test_nb),accuracy_score(y_test, y_pred_test_dt),accuracy_score(y_test, y_pred_test_svm),accuracy_score(y_test, y_pred_test_rf),accuracy_score(y_test, y_pred_test_knn),accuracy_score(y_test, y_pred_test_Ada),accuracy_score(y_test, y_pred_test_xgb)],
                     "Training_Accuracy":[accuracy_score(y_train, y_pred_train_lr),accuracy_score(y_train, y_pred_train_nb),accuracy_score(y_train, y_pred_train_dt),accuracy_score(y_train, y_pred_train_svm),accuracy_score(y_train, y_pred_train_rf),accuracy_score(y_train, y_pred_train_knn),accuracy_score(y_train, y_pred_train_Ada),accuracy_score(y_train, y_pred_train_xgb)]})

# %%
Accuracies
# Out:
#                       Model  Testing_Accuracy  Training_Accuracy
# 0       Logistic Regression          0.762807           0.763275
# 1               Navie_Bayes          0.803509           0.812865
# 2             Decision_Tree          0.911579           1.000000
# 3                       SVM          0.760702           0.762105
# 4  Random_Forest_Classifier          0.957193           1.000000
# 5                       KNN          0.894737           0.923509
# 6      Ada_Boost_Classifier          0.904561           0.905029
# 7                       XGB          0.973333           1.000000
